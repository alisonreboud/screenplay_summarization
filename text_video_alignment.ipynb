# %%
import pandas as pd
import os
from os import listdir
from tqdm import tqdm

# %%
eps=[]
path_screenplays_scenes='coref/csi-corpus/screenplay_summarization/scene_level_n_aspects'
path_timestamps='coref/csi-corpus/perpetrator_identification'

for ep in listdir(path_screenplays_scenes):
    #print(ep)
    annotated_scenes=pd.read_csv(path_screenplays_scenes+'/'+ep)
    eps.append(ep.split('.csv')[0])
    
print(eps)
    
erros=['s05e10', 's01e08', 's05e05']
print(erros)
# Out:
# ['s03e12', 's05e13', 's01e20', 's05e10', 's01e08', 's03e11', 's04e14', 's05e22', 's03e19', 's04e23', 's05e21', 's02e06', 's04e10', 's05e08', 's03e05', 's04e22', 's04e09', 's05e06', 's01e13', 's02e01', 's05e17', 's01e07', 's04e21', 's05e12', 's02e15', 's04e12', 's03e03', 's04e05', 's02e10', 's02e09', 's05e05', 's05e03', 's02e04', 's04e15', 's01e23', 's03e21', 's04e06', 's03e08', 's01e19']
# ['s05e10', 's01e08', 's05e05']

# %%
def replace_names(annoted_scenes):
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("david hodges", "davidhodges")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("david phillips", "DavidPhillips")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("mia dickerson", "MiaDickerson")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("detective chris cavaliere", "DetectiveChrisCavaliere")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("adam matthews", "AdamMatthews")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("judy tremont", "JudyTremont")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("marty gleason", "MartyGleason")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("meg cunningham", "MegCunningham")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("charlie pinscher", "CharliePincher")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("paul brady", "PaulBrady")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("erin brady", " ErinBrady")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("dan keaton", "DanKeaton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("tom cunningham", "TomCunningham")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("amy keaton", "AmyKeaton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("mallory stone", "MalloryStone")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("mrs basengi", "MrsBasengi")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("mr basengi", "MrBasengi")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("vanessa keaton", "VanessaKeaton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("amy keaton", "AmyKeaton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("alex stone", " AlexStone")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("melissa poolie", "MelissaPoolie")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("brenda peters", "BrendaPeters")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("joe peters", "JoePeters")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("David Hodges", "davidhodges")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("David Phillips", "DavidPhillips")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Mia Dickerson", "MiaDickerson")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Detective Chris Cavaliere", "DetectiveChrisCavaliere")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Adam Matthews", "AdamMatthews")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Judy Tremont", "JudyTremont")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Marty Gleason", "MartyGleason")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Meg Cunningham", "MegCunningham")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Charlie Pinscher", "CharliePincher")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Paul Brady", "PaulBrady")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Erin Brady", " ErinBrady")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Dan Keaton", "DanKeaton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Tom Cunningham", "TomCunningham")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Amy Keaton", "AmyKeaton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Mallory Stone", "MalloryStone")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Mrs. Basengi", "MrsBasengi")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Mr. Basengi", "MrBasengi")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Vanessa Keaton", "VanessaKeaton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Amy Keaton", "AmyKeaton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Alex Stone", " AlexStone")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Melissa Poolie", "MelissaPoolie")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Brenda Peters", "BrendaPeters")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("Joe Peters", "JoePeters")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("linley parker", "linleyparker")   
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("linley parker", "linleyparker")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("todd coombs", "toddcoombs")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("rogercoombs", "rogercoombs")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("kevin coombs", "kevincoombs")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("larry coombs", "larrycoombs")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("grissom sara", "grissomsara")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("samantha dean", "samanthadean")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("gus kenyon", "guskenyon")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("toby arcane", "tobyarcane")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("david phillips", "davidphillips")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("grissom sara", "grissomsara")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("joseph greene", "josephgreene")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("sam braun", "sambraun")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("teddy keller", "teddykeller")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("davis mullins", "davismullins")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("joelanders", "joelanders")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("matthew hawkins", "matthewhawkins")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("martin hawkins", "martinhawkins")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("yvonne hawkins", "yvonne hawkins")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("monica newman", "monicanewman")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("max newman", "maxnewman")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("peter berglund", "peterberglund")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("nicole exmoor", "nicoleexmoor")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("chuck darwell", "chuckdarwell")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("barry schickle", "barryschickle")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("julia barrett", "juliabarrett")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("chuck darwell", "chuckdarwell")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("barry schickel", "barryschickel")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("kelsey fram", "kelseyfram")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("dennis fram", "dennisfram")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("tammy felton", "tammyfelton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("bobby dawson", "bobbydawson")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("adam brower", "adambrower")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("brass grissom", "brassgrissom")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("max duncan", "maxduncan")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("adam brower", "adambrower")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("darin hanson", "darinhanson")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("tammy darin", "tammydarin")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("darin tammy", "darintammy")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("adam tammy", "adamtammy")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("douglas sampson", "douglassampson")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("dustin bale", "dustinbale")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("brass grissom", "brassgrissom")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("randy traschel", "randytraschel")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("pete banson", "petebanson")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("billy rattison", "billyrattison")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("las vegas", "lasvegas")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("sulik catherine", "sulikcatherine")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("john damen", "johndamen")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("danny pasqualle", "dannypasqualle")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("brody jones", "brodyjones")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("linda damen", "lindadamen")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("jane damen", "janedamen")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("harold haskins", "haroldhaskins")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("les dutton", "lesdutton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("ross halpo", "rosshalpo")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("manny saldano", "mannysaldano")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("chef petrov", "chefpetrov")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("petrov samsko", "petrovsamsko")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("david hodges", "davidhodges")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("nora easton", "noraeaston")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("daniel easton", "danieleaston")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("marty gibson", "martygibson")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("amy ennis", "amyennis")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("clyde hinton", "clydehinton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("kelly easton", "kellyeaston")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("nancy linden", "nancylinden")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("nanci linden", "nancilinden")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("jill frommer", "jillfrommer")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("julia reed", "juliareed")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("roger dunbar", "rogerdunbar")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("beth dunbar", "bethdunbar")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("myles ruben", "mylesruben")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("lori hutchins", "lorihutchins")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("brian haddick", "brianhaddick")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("debbie marlin", "debbiemarlin")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("howard tripton", "howardtripton")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("celeste turner", "celesteturner")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("vincent mendoza", "vincentmendoza")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("catherine willows", "catherinewillows")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("sam mendez", "sammendez")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("samuel mendez", "samuelmendez")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("brass sara", "brasssara")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("rufus sanders", "rufussanders")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("rufus sanders", "rufussanders")



    #print(result)
    
#eps.append(ep.split('.tsv')[0])
#print(df_timestamps)

    

    return annotated_scenes

# %%
def Diff(li1, li2):
    li_dif = [i for i in li1 + li2 if i not in li1 or i not in li2]
    return li_dif

# %%
#eps=['s04e23']

eps=['s01e20', 's05e10', 's01e08', 's03e11', 's04e14', 's05e22', 's03e19', 's04e23', 's05e21', 's02e06', 's04e10', 's05e08', 's03e05', 's04e22', 's04e09', 's05e06', 's01e13', 's02e01', 's05e17', 's01e07', 's04e21', 's05e12', 's02e15', 's04e12', 's03e03', 's04e05', 's02e10', 's02e09', 's05e05', 's05e03', 's02e04', 's04e15', 's01e23', 's03e21', 's04e06', 's03e08', 's01e19']


#for ep in listdir(path_timestamps):
for ep in eps:
    print(ep)
    df_timestamps=pd.read_csv(path_timestamps+'/'+ep+'.tsv',sep='\t')
    #print(df_timestamps)
    #result = pd.concat([df_start, df_end], axis=1)
    annotated_scenes=pd.read_csv(path_screenplays_scenes+'/'+ep.split('.tsv')[0]+'.csv')
    print(len(annotated_scenes))
    if ep=='s05e05':
        annotated_scenes=annotated_scenes.drop([19])
    print(annotated_scenes.scene_text[32])
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.lower() 
    annotated_scenes=replace_names(annotated_scenes)    
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace(r"'", r'"') # cope with different types of '/'for dialogue extraction
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace(r']$', '",') #allows to extract last dialogue normally not followed by , but ]
    
    
    
    dialogue_matches=annotated_scenes.scene_text.str.extractall(r"(?P<dialogue_matches>\[\[.*?\"\,)")
    #print(dialogue_matches)
    annotated_scenes['dialogue']=annotated_scenes.scene_text.str.extract(r"(?P<dialogue>\[\[.*?\"\,)")    
    #print(annotated_scenes.dialogue)
    annotated_scenes.non_dialogue=annotated_scenes.scene_text.str.replace(r"(?P<non_dialogue>\[\[.*?\"\,)",'')
    #print(annotated_scenes.scene_text.loc[1])
    #print(dialogue_matches.dialogue_matches[1])
    
    dialogue_matches.dialogue=dialogue_matches.dialogue_matches.groupby(level=0).apply(list)
    #print(dialogue_matches.dialogue)
    annotated_scenes.loc[annotated_scenes['dialogue'].notna(), 'dialogue'] = dialogue_matches.dialogue
    #print(annotated_scenes.loc[annotated_scenes['dialogue'].isna()])
    annotated_scenes.loc[annotated_scenes['dialogue'].isna(), 'dialogue'] = 'no dialogue'
    #print(annotated_scenes.dialogue[1])
    
    #print('----------------------------------------')
    i=1
 
    #print(annotated_scenes.scene_text[i])
    #print('----------------------------------------')
    #print(annotated_scenes.dialogue[i])
    #print('----------------------------------------')
    #print(annotated_scenes.non_dialogue[i])
    #print('----------------------------------------')

        
    

    
    
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("n't", "nt")
    annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("\[\[.*?\]\]", "")##removing speaker ex :[[Grisamm]]
    annotated_scenes['words']=annotated_scenes.scene_text.str.replace('[^\w\s]','').str.split().tolist()#removing punctuation and splitting
    #print(annotated_scenes.words.loc[1])
    #annotated_scenes['dialogue']=annotated_scenes.dialogue.str.replace('[^\w\s]','')
    #print(annotated_scenes.dialogue.loc[1])
    
    annotated_scenes['word_count']=annotated_scenes['words'].apply(len)#creating column with nbr of words per scene
    words_scenes=annotated_scenes.index.repeat(annotated_scenes['word_count'].tolist())# creating a column repeating the index according to nbr of words per scene
    #print(annotated_scenes.words[9])
    #print(annotated_scenes['word_count'][8])
    words_scenes=words_scenes[0:len(df_timestamps)] #cutting list to match with the word count of timestamped file
    df_timestamps['sceneID']=words_scenes
    #print(df_timestamps['sceneID'])
    annotated_scenes['start']=df_timestamps.groupby(by=["sceneID"])['start_time'].first()#keep first start_time of each scene
    print(df_timestamps.groupby(by=["sceneID"])['start_time'])
    #print(len(annotated_scenes))
    annotated_scenes['end']=df_timestamps.groupby(by=["sceneID"])['end_time'].last()#keep last end_time of each scene
    s = df_timestamps['word'].tolist()
    print(len(s))      
    scenes= annotated_scenes['words'].tolist()
    flat_list = [item.lower() for sublist in scenes for item in sublist]
    print(len(flat_list))
    print(Diff(flat_list,s))
    #print(annotated_scenes['start'])
    #print(df_timestamps[['start_time','end_time']][df_timestamps['sceneID']==i])
    #print(annotated_scenes.start[i])
    #print('----------------------------------------')
    #print(annotated_scenes.end[i])
    #print('----------------------------------------')
    print(annotated_scenes['start'][32])
    print(annotated_scenes['end'][32])
    annotated_scenes['start'][33]='41.26'
    if annotated_scenes['start'].isnull().values.any():
        print('errrrroooooooooooooooooor')
        #print(annotated_scenes['start'])
        errors.append(ep)
    #print(annotated_scenes.scene_text[1])
    #print(annotated_scenes.dialogue[0])
    #print(annotated_scenes.non_dialogue[0])
    
    
    
    
    

    
    #print(len(words_scenes))
    #print(len(df_timestamps))
    #print(annotated_scenes['word_count'].sum())
    print('----------------------------------------')

    #print(result)
    
#eps.append(ep.split('.tsv')[0])
#print(df_timestamps)
# Out:
# s01e20
# 33
# [' ( GRISSOM and DR. GILBERT sit outside the front of the college . )', ' [[Grissom]] some people are just afraid', " [[Jane_Gilbert]] and that 's why they killed brian", ' [[Jane_Gilbert]] because he was different', " [[Jane_Gilbert]] you do n't see us as different", ' ( Shakes his head . )', " [[Grissom]] you 're not", ' [[Jane_Gilbert]] who taught you to sign ?', ' [[Grissom]] my mother', ' [[Jane_Gilbert]] tell me about her', ' [[Jane_Gilbert]] and use your hands', " [[Jane_Gilbert]] you 're a little rusty", ' ( GRISSOM smiles sheepishly at her . )', ' [[Grissom]] she lost her hearing when she was eight', ' ( Off of GRISSOM , camera shot of DR. GILBERT . )', ' [[Grissom]] ... loved to swim', ' [[Grissom]] i asked her what it was like to be deaf', ' [[Grissom]] she told me to stick my head under the water', ' [[Jane_Gilbert]] true', " [[Grissom]] she taught me not to make fun of 'she ' ... 'you ' ... 'everyone ' ... 'the same '", ' ( Camera is behind DR. GILBERT , off her shoulder at GRISSOM then slowly pulls back . )']
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x7f7dd9913a20>
# 7840
# 7922
# /home/portege24/.local/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# /home/portege24/.local/lib/python3.6/site-packages/ipykernel_launcher.py:32: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# ['re', 'nt', 'nt', 'sgt', 'oriley', 'm', 'sgt', 'oriley', 'oriley', 'nt', 'hitandrun', 'nt', 'll', 'nt', 'nt', 'nt', 'nt', 're', '_shooter_s_pov_', 'm', 'm', 'ninemillimeter', 'd', 'mccarty', 'ns12', 'ninemillimeter', 'nt', 'm', 'stokes', 're', 'nt', '1000', 'nt', 're', 'nt', 'nt', 'nt', 'm', 'd', 'd', 'm', 'nt', 're', 're', 'll', 'nt', 'm', 're', 'timesensitive', 'd', 're', 'nt', 'm', 'm', 'nt', 'nt', 'nt', 'm', 're', 'm', 're', 'nt', 'arrington', 'nt', 'nt', 'nt', 'arrington', 'nt', 're', 'arrington', 're', 'arrington', 've', 've', 'm', '517', 'nt', 'nt', 'nt', 'nonresponse', 're', 'm', 'mmhmm', 'photoed', '11033', 'nt', 'nt', 'nt', 'll', 'll', 'glowstick', 'nt', 'p23575', 'bluedotted', 'jane', 're', 'jane', 'nt', 'm', 'nt', 'sgt', 'oriley', 'm', 'nt', 'nt', 'nt', 're', 'sgt', 'oriley', 're', 'nt', 'nt', 're', 'breachface', 'twobit', 're', 'nt', 'nt', 'mccarty', 've', 'd', 'nt', 'nt', 'dayglo', 'twentyyearold', 'sgt', 'oriley', 'ii', 'nt', 'rucker', 'jane', 'd', 're', 'hitandrun', 'nt', 've', 'nt', 'm', 'nt', 'sx', 're', 'nt', 'll', 'nt', 'm', 've', '
t', 'd', 's', 's', 'yall', 'valdez', 's', 'reinterviews', 'nt', 'll', 'tunnelvisioned', 's', 's', 'd', 'nt', 's', 's', 'parttime', 'valdez', 'excon', 'coworker', 's', 'nt', 's', 'll', 'nt', 'thirtyeight', 'thirtyeight', 'nt', 'reporter', 's', 's', 'nt', "'s", "'re", "'re", "'re", "n't", 'ho-hos', "'s", "n't", 'ho-hos', 'ho-ho', "'s", 'grissomcatherine', "'ve", "n't", "'re", "'s", 'catherinewarrick', "'d", "5'2", 'henryturner', "[_fromansky_'s_pov_]", 'maybe-maybe', "'d", "'m", "'s", "n't", "'s", "'re", "'ve", "n't", "'s", "'m", "'s", "'s", "'re", "n't", "'s", "'s", "'s", "n't", "'re", "'s", "'ve", "'m", "n't", 'i-i-i', "n't", 'he-he', "'d", "n't", "'s", "'s", "n't", "'s", "'ll", 'reedjulia', "'s", "'s", "n't", "n't", "n't", "'ll", "'ve", "'s", "'re", "n't", "'s", "'re", "'s", "'s", "'s", "'re", 'bastard', "'s", "'s", "'s", "n't", "'s", 'warricksara', "'s", "'s", "'s", "'s", 'tec-9', 'double-aught', "'ve", "'s", "'s", "'s", "n't", "'d", "n't", "'re", "'re", "'re", "'s", "n't", "'re", '[_video_view_]', "'m", "'re", "'m", "n't", "'s", "n't", "'s", "'d", "'re", "'s", "'s", "'s", 'mm-hmm', 'five-year', "'s", 'close-range', 'tec-9', 'distant-range', 'medium-caliber', 'distant-range', 'medium-caliber', 'medium-caliber', "'s", 're-questions', "'s", "n't", "'s", "n't", "n't", "what's-what", "'s", "'s", "n't", "'re", 'sh-she', "n't", "'m", 'tec-9', 'walk-through', "'s", "'ll", "'ll", "'d", "'s", "n't", "n't", "n't", "'m", "n't", "'d", "n't", "n't", "'s", "'s", "n't", "'s", "'m", "'s", "'s", "n't", "n't", "'s", "'m", "'re", '[_night_]', 'warrickcatherine', "'ll", "'s", "'m", "n't", "'ll", "n't", "'ll", '[_the_market_]', "'s", "n't", 'toddhallickey', 'toddhallickey', "n't", "n't", 'test-drove', "n't", "n't", "'s", "'m", "n't", "'re", 'toddhallickey', "'s", "'s", "'d", "'s", "'s", "'s", 'toddhallickey', 'grissomwarrick', "'s", "'s", "'s", "'s", "n't", "'d", "'s", "'s", "y'all", 'raulvaldez', "'s", 're-interviews', "n't", "'ll", 'tunnel-visioned', "'s", "'s", "'d", "n't", "'s", "'s", 'part-time', 'raulvaldez', 'ex-con', 'co-worker', "'s", "n't", "'s", "'ll", "n't", 'thirty-eight', 'thirty-eight', "n't", "'s", "'s", "n't"]
# 00:29:24.686000
# 00:30:06.470000
# ----------------------------------------
# s05e22
# 32
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-d4c195c42542> in <module>
#      14     if ep=='s05e05':
#      15         annotated_scenes=annotated_scenes.drop([19])
# ---> 16     print(annotated_scenes.scene_text[32])
#      17     annotated_scenes.scene_text = annotated_scenes.scene_text.str.lower()
#      18     annotated_scenes=replace_names(annotated_scenes)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 32

# %%
print(errors)
# Out:
# []

# %%
#for ep in listdir(path_timestamps):
#eps=['s04e23']
for ep in eps:
    print(ep)#
    df_timestamps=pd.read_csv(path_timestamps+'/'+ep+'.tsv',sep='\t')
    #print(df_timestamps)
    #result = pd.concat([df_start, df_end], axis=1)
    annotated_scenes=pd.read_csv(path_screenplays_scenes+'/'+ep.split('.tsv')[0]+'.csv')

    #print()
    


    
    #print(a.get_level_values(0))
    #a2 = a.unstack()
    
    #print(len(a2[2]))
    #cols=[i for i in range(len(a2.columns))]
    #annotated_scenes['dialogue'] = annotated_scenes[cols].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)
    #a2.columns = a2.columns.droplevel()
    #annotated_scenes.join(a2)
    #print(a2)
# Out:
# s03e12
# 0                                                   NaN
# 1                                [[Lead_Man_1]] i do n'
# 2                                                   NaN
# 3                          [[Grissom]] well , someone '
# 4                                                   NaN
# 5                                     [[Grissom]] you '
# 6     [[Sara]] you know the average nevadan generate...
# 7     [[Robbins]] the electrolyte and glucose levels...
# 8     [[Catherine]] i think i may have something her...
# 9     [[Catherine]] heard you got to be superhero to...
# 10              [[Sara]] all right , what do we know ?'
# 11     [[Robbins]] pulled it from the l4-l5 interspace'
# 12                [[Nick]] hey , is this all of them ?'
# 13                                  [[Catherine]] let '
# 14    [[Sara]] if the vic was in here blood would ha...
# 15    [[Daniel_Easton]] you found blood ... in my tr...
# 16                           [[Warrick]] i hear david '
# 17       [[Nancy_Linden]] may i help you , gentlemen ?'
# 18         [[Nancy_Linden]] so , this was ... is fred '
# 19                 [[Robbins]] okay , david , take two'
# 20                     [[Brass]] no luck on amy ennis '
# 21    [[David_Phillips]] if the poison was administe...
# 22                           [[Sara]] well , she was n'
# 23    [[Catherine]] according to greg , the hairs an...
# 24    [[Catherine]] ... want to mulligan on your fir...
# 25                                     [[Sara]] i do n'
# 26    [[Daniel_Easton]] she came back about a month ...
# 27                                                  NaN
# 28                                                  NaN
# 29                        [[Charlie_Easton]] so , she '
# 30    [[Nora_Easton]] last time i saw my mother , i ...
# 31                                                  NaN
# 32                                                  NaN
# 33    [[Nick]] this is where i found the hairs , in ...
# 34    [[Warrick]] that unknown substance i collected...
# 35    [[Grissom]] we found reptile skin on your jack...
# 36                    [[Marty_Gibson]] watch your step'
# 37                           [[Daniel_Easton]] i did n'
# 38     [[Jessie_Menken]] scales found on your suspect '
# 39    [[Greg]] okay , blood from the bedroom chair a...
# 40             [[Nora_Easton]] the bracelet was a gift'
# 41               [[Catherine]] you sick son of a bitch'
# 42                     [[Warrick]] what do you mean , '
# 43        [[Snake_Handler]] girl called all hysterical'
# 44                              [[Marty_Gibson]] nanci'
# 45    [[Nurse]] okay , if i can just have you lay back'
# 46                                       [[Sara]] she '
# 47           [[Catherine]] nora , is this your shirt ?'
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 0          0  [' ( A dark colored large bird flies across th...           0
# 2          2  [' ( The camera focuses and refocuses on the b...           0
# 4          4  [' ( GRISSOM puts the eye in a dish and takes ...           0
# 27        27  [' ( CATHERINE pulls the bed covers back and c...           0
# 28        28  [" ( NICK uses the ALS in CHARLIE 'S bedroom ....           0
# 31        31  [" ( CATHERINE uses the ALS in NORA 'S bedroom...           0
# 32        32  [' ( SARA uses the ALS in the kitchen . )', ' ...           0
# 40        40  [' ( CATHERINE questions NORA EASTON . )', ' [...           0
# 41        41  [' ( CATHERINE walks rapidly through the hallw...           0
# 42        42  [' ( GREG shows WARRICK and GRISSOM the test r...           0
# 43        43  [' ( Camera pans across the counter where NANC...           1
# 44        44  [' ( MARTY GIBSON is in handcuffs leading GIBS...           1
# 45        45  [' ( NORA EASTON is having a pelvic examinatio...           0
# 46        46  [' ( SARA and CATHERINE are in the lounge . )'...           1
# 47        47  [' ( CATHERINE interviews NORA EASTON . )', ' ...           1
#
#      aspects dialogue
# 0       None      NaN
# 2       None      NaN
# 4       None      NaN
# 27      None      NaN
# 28      None      NaN
# 31      None      NaN
# 32      None      NaN
# 40      None      NaN
# 41      None      NaN
# 42      None      NaN
# 43  Evidence      NaN
# 44      None      NaN
# 45      None      NaN
# 46  Evidence      NaN
# 47    Motive      NaN
# s05e13
# 0                                    [[Foreman]] joe !'
# 1                                                   NaN
# 2                        [[Robbins]] two sets of hands'
# 3                                       [[Grissom]] so'
# 4                                         [[Sara]] wow'
# 5                                                   NaN
# 6     [[Sara]] ladies and gentlemen , miss jane doe ...
# 7                      [[Nurse]] you hitting every e.r'
# 8                           [[Andrew_Melton]] why do n'
# 9     [[Conrad_Ecklie]] you are a law enforcement of...
# 10                                   [[Warrick]] what '
# 11    [[Greg]] catherine , i heard ecklie suspended ...
# 12           [[Warrick]] a lot of blood on that blouse'
# 13    [[Ronnie_Litre]] all right , first we mirror i...
# 14         [[Vlad]] you have appointment for haircut ?'
# 15              [[Ken_Wellstone]] uh , she cut my hair'
# 16                                                  NaN
# 17                             [[Sara]] well , if you '
# 18                                        [[Sara]] it '
# 19                                                  NaN
# 20    [[Brass]] so the tar from your carpet matches ...
# 21                                                  NaN
# 22           [[Warrick]] all of the blood on svetlana '
# 23                             [[Chloe_Daniels]] what '
# 24    [[Catherine]] jagged on one side , smooth on t...
# 25    [[Warrick]] the stain on the chair was aubergi...
# 26                     [[Brass]] everything in order ?'
# 27                                                  NaN
# 28                             [[Catherine]] svetlana '
# 29    [[Ronnie_Litre]] all right , the relative size...
# 30    [[Warrick]] according to your credit card stat...
# 31    [[Brass]] boy , women can really drive you cra...
# 32             [[June_Melton]] andrew , what happens ?'
# 33                          [[Catherine]] okay , here '
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 1          1  [' ( The large block of tar and rock containin...           0
# 5          5  [' ( David Phillips examines the remains . )',...           0
# 16        16  [' ( Nick walks into the darkened room carryin...           0
# 19        19  [" ( Hodges works on processing the black spot...           0
# 21        21  [' ( Warrick is spraying the clothes with lumi...           0
# 27        27  [' ( Catherine scans the necklace into the com...           0
#
#    aspects dialogue
# 1     None      NaN
# 5     None      NaN
# 16    None      NaN
# 19    None      NaN
# 21    None      NaN
# 27    None      NaN
# s01e20
# 0                    [[Charlotte]] that club was hot !'
# 1                                             [[Sgt._O'
# 2                                       [[Sara]] what '
# 3      [[Dr._Albert_Robbins]] printed your hit-and-run'
# 4                       [[Nick]] one person dead , it '
# 5                           [[Grissom]] mrs clemonds ?'
# 6                           [[Dr._Albert_Robbins]] it '
# 7     [[Nick]] another nine-millimeter , just like o...
# 8                                       [[Brass]] okay'
# 9                                  [[Sara]] dr gilbert'
# 10                                     [[Warrick]] hey'
# 11                            [[Grissom]] dr gilbert ?'
# 12                [[Jane_Gilbert]] i did nothing wrong'
# 13                  [[Grissom]] this explains what we '
# 14                             [[Catherine]] grissom !'
# 15    [[Warrick]] those the tire treads from the cri...
# 16      [[Brass]] guess who used to sign brad kendall '
# 17                       [[Greg_Sanders]] i am the man'
# 18    [[Jane_Gilbert]] you found the car that ran ov...
# 19                                     [[Warrick]] hmm'
# 20                                [[Randy_Painter]] i '
# 21                            [[Catherine]] talk to me'
# 22    [[Nick]] if it was a hit , the guy came to the...
# 23                      [[Warrick]] adam walkey does n'
# 24    [[Nick]] you really think erin knew she was pr...
# 25                             [[Sara]] check this out'
# 26                                            [[Sgt._O'
# 27                      [[Jane_Gilbert]] you said you '
# 28                                 [[Nick]] 911 page ?'
# 29                               [[Brad_Kendall]] me ?'
# 30                                            [[Sgt._O'
# 31             [[Brad_Kendall]] what am i looking at ?'
# 32             [[Grissom]] some people are just afraid'
# Name: dialogue, dtype: object
# Empty DataFrame
# Columns: [scene_id, scene_text, in_summary, aspects, dialogue]
# Index: []
# s05e10
# 0            [[Brass]] so , the gang unit says our d.b'
# 1     [[Greg]] somebody tried to just throw him out ...
# 2                                      [[Warrick]] hey'
# 3     [[Overhead]] ... security officers for lockdow...
# 4                                    [[Dr._Franks]] i '
# 5                                                   NaN
# 6                              [[Robbins]] the victim '
# 7                              [[Lt._Arthur_Chen]] it '
# 8                                  [[Sofia_Curtis]] i '
# 9                                     [[Warrick]] okay'
# 10    [[Sara]] i went through child abuse cases , lo...
# 11    [[Lorna_Tenney]] so , which one of my kids is ...
# 12                                                  NaN
# 13    [[David_Hodges]] heard you had a real sphincte...
# 14                                   [[Mr._Mendez]] i '
# 15                                                  NaN
# 16                                    [[Glynnis]] guys'
# 17                           [[Delia_Brooks]] the boy '
# 18                             [[Catherine]] hey , mia'
# 19    [[Sofia_Curtis]] heard you found a print on th...
# 20    [[Phillip_Riley]] i hope you can tell me what ...
# 21               [[Warrick]] aw , it looks good on you'
# 22                                                  NaN
# 23                                                  NaN
# 24                         [[Nick]] fire in the hole !'
# 25    [[Catherine]] we now know the cops were not re...
# 26                             [[Margaret_Finn]] what '
# 27    [[Divine]] forty buys the lips , a hundy gets ...
# 28          [[Catherine]] taking your pet for a walk ?'
# 29     [[Divine]] we been sitting here a long-ass time'
# 30                          [[Neighborhood_Kid]] what '
# 31    [[Brass]] so , turns out that mom was sending ...
# 32                          [[Brass]] so , seattle p.d'
# 33                                                  NaN
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 5          5  [' ( The lid is removed from the rubber bin Sa...           0
# 12        12  [' ( Greg has the rubber trash bin suspended i...           0
# 15        15  [' ( Catherine scans in a print into the compu...           0
# 22        22  [' ( Mia takes out the gun from the evidence b...           1
# 23        23  [' ( Camera pans down the table of shoes from ...           0
# 33        33          [' ( Sara is at the laptop computer . )']           0
#
#      aspects dialogue
# 5   Evidence      NaN
# 12      None      NaN
# 15  Evidence      NaN
# 22  Evidence      NaN
# 23      None      NaN
# 33      None      NaN
# s01e08
# 0                                                   NaN
# 1                                [[Brass]] oh ... you '
# 2     [[Recorded_Voice]] man on mini-recorder : my n...
# 3     [[Grissom]] shibley , take this recorder to th...
# 4                                        [[Nick]] oh !'
# 5                               [[Grissom]] okay , we '
# 6     [[Warrick]] everyone still breathing in that c...
# 7                            [[Dr._Albert_Robbins]] i '
# 8              [[Nick]] the skid start way up the road'
# 9                                 [[Sara]] hey , evans'
# 10                                        [[Sara]] wow'
# 11    [[Paige_Harmon]] i thought you were going to t...
# 12             [[Nick]] mr backseat going to make it ?'
# 13                               [[Greg_Sanders]] okay'
# 14            [[Warrick]] supergluing the entire car ?'
# 15                                      [[Catherine]] '
# 16    [[Disco_Placid]] yeah , better leave young thi...
# 17                                     [[Mandy]] so i '
# 18    [[Sara]] i did some comparative digging on bot...
# 19                  [[Grissom]] can we see the print ?'
# 20                             [[Warrick]] so ... who '
# 21                          [[Grissom]] mr millander ?'
# 22               [[Grissom]] i envy you , mr millander'
# 23                                 [[Warrick]] finally'
# 24                                     [[Brass]] three'
# 25                             [[Brass]] dr livingston'
# 26                   [[Warrick]] you got his clothes ?'
# 27                       [[Greg_Sanders]] so ... what '
# 28                                   [[Nick]] banglor '
# 29                                   [[Grissom]] there'
# 30                           [[Brass]] how you doing ?'
# 31           [[Dr._Leever]] two minutes , understand ?'
# 32                                  [[Nick]] hey , hey'
# 33             [[Nick]] well , the only thing we did n'
# 34             [[Brass]] can we start again , please ?'
# 35    [[Grissom]] so when i picked up the hand he mu...
# 36     [[Sara]] typing in search word : paul millander'
# 37      [[Sara]] age 42 , five-eleven , male caucasian'
# 38                                                  NaN
# 39                               [[Officer]] all clear'
# 40                  [[Paul_Millander]] mr grissom in ?'
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 0          0  [' ( Camera close up of a tumbler . )', ' ( So...           1
# 38        38  [' ( The police vehicle stops . )', ' ( OFFICE...           0
# 40        40  [' ( The RECEPTIONIST looks up from her desk a...           0
#
#    aspects dialogue
# 0   Victim      NaN
# 38    None      NaN
# 40    None      NaN
# s03e11
# 0                        [[Delivery_Man]] hey , harlan'
# 1                                                   NaN
# 2                          [[Brass]] ever wonder what '
# 3             [[Grissom]] the last remains of john doe'
# 4                                              [[Det._'
# 5                                         [[Sara]] hey'
# 6                                 [[Robbins]] since i '
# 7                            [[Grissom]] petrov samsko'
# 8          [[Warrick]] different sole , different size'
# 9     [[Robbins]] the trans-section of the left wris...
# 10              [[Hostess]] uh , debreff , please hold'
# 11                     [[Les_Dutton]] are you sure it '
# 12                            [[Grissom]] okay , this '
# 13                          [[Grissom]] ah , excuse me'
# 14                                        [[Sara]] hey'
# 15                            [[Sara]] the windshield '
# 16    [[Nick]] fresh off an airplane from a conferen...
# 17          [[Grissom]] presence of blood on the drain'
# 18    [[John_Damen]] oh , uh , this is the clearest ...
# 19                                [[Les_Dutton]] that '
# 20    [[Danny_Pasqualle]] what am i going to do , su...
# 21                                                  NaN
# 22                     [[Greg]] blade # 25 : not human'
# 23                                             [[Det._'
# 24    [[Greg]] did you know that some doctors believ...
# 25    [[Grissom]] you can see why i might have a har...
# 26    [[Brass]] so , you snuck in the place to grind...
# 27                                [[Ross_Halpo]] that '
# 28    [[Warrick]] brody , we have your shoeprint in ...
# 29           [[Sara]] bipolar girl meets a bipolar guy'
# 30                           [[Catherine]] greg , how '
# 31       [[Catherine]] may i see your nails , please ?'
# 32                                             [[Det._'
# 33                  [[David_Hodges]] wools are worsted'
# 34    [[Catherine]] so that sample i collected match...
# 35    [[Warrick]] mrs damen , our detective found th...
# 36                  [[Greg]] the blouse from your vic '
# 37                                 [[Catherine]] what '
# 38                                   [[Grissom]] that '
# 39       [[Catherine]] a murdered chef in your kitchen'
# 40                                      [[Brass]] how '
# 41                                      [[Brass]] let '
# 42                  [[Grissom]] why did you kill him ?'
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 1          1  [' ( HARLAN opens up the main meat packing are...           1
# 21        21  [" ( The technician takes a syringe and takes ...           0
# 40        40  [' ( GRISSOM meets BRASS outside in the hallwa...           0
# 41        41  [" ( BRASS walks into the interview room and w...           0
# 42        42  [' ( CHEF ROSS HALPO in handcuffs is being esc...           1
#
#         aspects dialogue
# 1   Crime scene      NaN
# 21         None      NaN
# 40         None      NaN
# 41         None      NaN
# 42       Motive      NaN
# s04e14
# 0           [[Officer_Clay]] what do you need to get ?'
# 1                     [[Mr._Reed]] get out of my way !'
# 2     [[Brass]] officer clay entered the store unawa...
# 3          [[Brass]] all right , tell me what happened'
# 4     [[Catherine]] everybody , could i please have ...
# 5     [[Grissom]] what happened to your assault in h...
# 6     [[Bagboy]] those two guys came out of nowhere ...
# 7                                                   NaN
# 8                    [[Manager]] well , you know , we '
# 9                                                   NaN
# 10    [[Warrick]] you know , this guy hit a $ 75 jac...
# 11    [[Woman_Cashier]] we all just started running ...
# 12                              [[David_Phillips]] hey'
# 13          [[Mr._Reed]] i was , uh ... holding julia '
# 14                                     [[Robbins]] we '
# 15                    [[David_Phillips]] officer clay '
# 16    [[Catherine]] hi , i was wondering if i might ...
# 17    [[Catherine]] b*st*rd was behind her the whole...
# 18                           [[Warrick]] officer clay '
# 19                 [[Bobby_Dawson]] firing two shots !'
# 20              [[Warrick]] grissom , we got a problem'
# 21               [[Brass]] how you feeling , officer ?'
# 22    [[Celeste_Turner]] there was no way i could wa...
# 23    [[Nick]] double counts , two people in the roo...
# 24                           [[Nick]] see that light ?'
# 25    [[Grissom]] afis hits on our suspects , both j...
# 26    [[Mr._Reed]] look , i came here to pick up my ...
# 27    [[Grissom]] highlight the shots that killed th...
# 28    [[IAB_Officer]] at the walk-through you said t...
# 29                           [[Warrick]] a little over'
# 30            [[Warrick]] you can see me now , right ?'
# 31    [[Warrick]] we found metal paint scrapings and...
# 32    [[Hodges]] ran your paint chips through ppg an...
# 33    [[Officer_Fromansky]] before this goes any dee...
# 34    [[Brass]] so , this car was reported stolen ab...
# 35                            [[Brass]] todd hallickey'
# 36                               [[Brass]] you would n'
# 37                              [[Warrick]] hallickey '
# 38                 [[Bagboy]] i got to change my pants'
# 39    [[Catherine]] you left something in the store ...
# 40    [[Warrick]] you know , hodges already analyzed...
# 41                     [[Nick]] hey , catherine , how '
# 42    [[Catherine]] you used to part-time at the for...
# 43    [[Reporter]] officer fromansky , if you could ...
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 7          7  [' ( GRISSOM processes the scene around the de...           0
# 9          9   [' ( WARRICK checks the win at the machine . )']           0
# 40        40  [' ( GRISSOM looks through the scope . )', ' (...           1
# 41        41  [' ( NICK catches up with CATHERINE in the hal...           0
# 42        42  [' ( CATHERINE interviews CELESTE TURNER . )',...           1
# 43        43  [' ( OFFICER FROMANSKY receives an award at th...           0
#
#    aspects dialogue
# 7     None      NaN
# 9     None      NaN
# 40    None      NaN
# 41    None      NaN
# 42    None      NaN
# 43    None      NaN
# s05e22
# 0                                     [[Catherine]] hi'
# 1         [[Adam_Novak]] no way you were never married'
# 2                                 [[Catherine]] i ca n'
# 3                                  [[Catherine]] hello'
# 4                        [[Grissom]] i appreciate this'
# 5     [[Det._Vartann]] you see anybody get out of th...
# 6     [[Officer]] except for the saturn , all the ca...
# 7     [[Robbins]] i dug it out of the right frontal ...
# 8               [[Sara]] so , judge wilson tells me i '
# 9                              [[Catherine]] lindsey !'
# 10              [[Hodges]] results from alice granger '
# 11                                         [[Greg]] yo'
# 12    [[Det._Vartann]] were you jealous , mr granger ?'
# 13                     [[Det._Vartann]] excuse me , i '
# 14    [[Catherine]] gil , the suspect has a laptop i...
# 15               [[Det._Vartann]] you are a real prize'
# 16                                        [[Greg]] hey'
# 17    [[Adam_Novak]] was it necessary to show up at ...
# 18    [[Adam_Novak]] at a bar that time of night , we '
# 19    [[Adam_Novak]] i know when a woman is going to...
# 20    [[Conrad_Ecklie]] just walk me through your in...
# 21                  [[David_Phillips]] look familiar ?'
# 22             [[Co-worker_1]] holly was just promoted'
# 23        [[Catherine]] hell of a backlog , here , doc'
# 24                                        [[Nick]] hey'
# 25                                     [[Voice]] 9-1-1'
# 26    [[Grissom]] mr novak , would you stick out you...
# 27                                  [[Catherine]] nick'
# 28                               [[Det._Vartann]] let '
# 29    [[Catherine]] i mean , lucky for you , the hig...
# 30         [[Catherine]] you made one mistake , though'
# 31    [[Grissom]] you figured out the source of the ...
# Name: dialogue, dtype: object
# Empty DataFrame
# Columns: [scene_id, scene_text, in_summary, aspects, dialogue]
# Index: []
# s03e19
# 0                                  [[Woman]] this wo n'
# 1                                 [[Woman]] ... there '
# 2                                 [[Catherine]] whoo !'
# 3                                  [[Robbins]] it was '
# 4                       [[Movie_Goer]] i only noticed '
# 5                                   [[Nick]] detective'
# 6                    [[Greg]] question is not what we '
# 7                                                   NaN
# 8                         [[Archie]] is that our guy ?'
# 9                                                   NaN
# 10                                 [[Sara]] hey , guys'
# 11                         [[Grissom]] audrey hilden ?'
# 12                 [[Audrey_Hilden]] he was my dentist'
# 13    [[Warrick]] geez , what was this kid , torture...
# 14                                  [[Catherine]] do n'
# 15                            [[Brass]] okay ... here '
# 16         [[Warrick]] this where the limbo party is ?'
# 17                                    [[Sara]] nothing'
# 18               [[Usher]] i was getting myself a soda'
# 19                             [[Catherine]] excuse me'
# 20    [[Greg]] 99 bottles of beer on the wall / 99 b...
# 21                                      [[Warrick]] i '
# 22                            [[Hodges]] spiral gouges'
# 23    [[Catherine]] so , the gloves match the palm p...
# 24                           [[Brass]] you hear that ?'
# 25    [[Catherine]] she used an extension cord and t...
# 26                      [[Grissom]] catherine ... she '
# 27                        [[Warrick]] venus and serena'
# 28                           [[Kevin_McCallum]] timmy '
# 29                              [[Kevin_McCallum]] it '
# 30                         [[Catherine]] well , there '
# 31                     [[Anthony_Haines]] audrey who ?'
# 32                                      [[Warrick]] i '
# 33                                        [[Sara]] hey'
# 34    [[Catherine]] so , get this -- anthony haines ...
# 35                                                  NaN
# 36    [[J.J.]] we go to the warehouse all the time ....
# 37           [[Earl]] i ride bmx bikes ... play soccer'
# 38             [[Zachary]] we were just messing around'
# 39                        [[Kevin_McCallum]] what up ?'
# 40    [[Kevin_McCallum]] timmy was a big fan of all ...
# 41                          [[kid]] come on , hit it !'
# 42                     [[Catherine]] langly and langly'
# 43                                  [[Man]] i said he '
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 7          7  [' ( JACQUI carefully takes the substances stu...           0
# 9          9  [' ( NICK stands in the middle of the warehous...           0
# 35        35  [' ( Two mannequins hands are set up on the co...           0
# 40        40  [" ( O'RILEY interviews KEVIN McCALLUM . )", '...           0
# 41        41  [' ( Back in the lab , NICK , SARA and WARRICK...           1
# 42        42  [' ( CATHERINE and GRISSOM both sit on chairs ...           1
# 43        43  [' ( On screen , the man takes out a gun and f...           0
#
#    aspects dialogue
# 7     None      NaN
# 9     None      NaN
# 35    None      NaN
# 40    None      NaN
# 41    None      NaN
# 42    None      NaN
# 43    None      NaN
# s04e23
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                             [[Linley_Parker]] help !'
# 4                             [[Voice_Of_EMT]] victim '
# 5                                                   NaN
# 6     [[Nick]] no skid marks , no signs of another v...
# 7                                          [[Sara]] i '
# 8                             [[Linley_Parker]] there '
# 9     [[Forensic_Artist_(woman)]] what do you rememb...
# 10                                                  NaN
# 11    [[Greg]] grissom , i have some information tha...
# 12    [[Warrick]] victim was a 32-year-old caucasian...
# 13                            [[Linley_Parker]] there '
# 14    [[Woman_(patient)]] my husband keeps dropping ...
# 15    [[Man]] single file , stop at your number on t...
# 16                                     [[Officer]] he '
# 17    [[Nick]] i compared the eight pairs of shoes w...
# 18                                 [[Brass]] dr coombs'
# 19                              [[Linley_Parker]] you '
# 20                                [[Sara]] i hear you '
# 21                                                  NaN
# 22    [[Larry_Coombs]] yeah , i read all about it in...
# 23                                                  NaN
# 24     [[Bailey_Coombs]] you want a sample of my dna ?'
# 25                                                  NaN
# 26                                 [[Sara]] hey , how '
# 27                               [[Catherine]] willows'
# 28                        [[Catherine]] where is she ?'
# 29                                     [[Grissom]] hey'
# 30                        [[Dispatch]] the is dispatch'
# 31    [[Nick]] her carrier accepted the attorney gen...
# 32                     [[Nick]] two hundred fifty feet'
# 33                                                  NaN
# 34                [[Sara]] checked with county records'
# 35                                        [[Robbins]] '
# 36                  [[Det._Vartann]] what do you got ?'
# 37    [[Det._Vartann]] so , you were home last night ?'
# 38                               [[Grissom]] dr coombs'
# 39                              [[Warrick]] whew , man'
# 40    [[Grissom]] according to the dna , the blood f...
# 41    [[Grissom]] would you strip down to your short...
# 42                                                  NaN
# 43                  [[Todd_Coombs]] this is harassment'
# 44            [[Brass]] state your name for the record'
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 0          0  [' ( The camera moves through the casino main ...           1
# 1          1  [' ( LINLEY PARKER walks out across the parkin...           0
# 2          2  [' ( LINLEY PARKER stands in front of her open...           0
# 5          5  [' ( Open on the cracked glass door . )', ' ( ...           0
# 10        10  [' ( CATHERINE runs a plate search for the num...           0
# 21        21  [' ( SARA does her research . )', ' ( First sc...           0
# 23        23  [' ( Computer close up on: )', ' ( The Search ...           0
# 25        25  [' ( Computer close up on: )', ' ( The Search ...           0
# 33        33  [" ( Open on LINLEY 'S feet . )", ' ( A camera...           0
# 40        40  [" ( CATHERINE stares a the wall covered with ...           1
# 41        41  [" ( TODD COOMBS is standing in the waiting ro...           1
# 42        42  [" ( GRISSOM does some research into TODD COOM...           0
# 43        43  [" ( GRISSOM ties a tube around TODD COOMBS ' ...           0
# 44        44  [' ( BRASS interviews TODD COOMBS . )', ' ( A ...           1
#
#      aspects dialogue
# 0     Victim      NaN
# 1       None      NaN
# 2       None      NaN
# 5       None      NaN
# 10      None      NaN
# 21      None      NaN
# 23      None      NaN
# 25      None      NaN
# 33      None      NaN
# 40  Evidence      NaN
# 41  Evidence      NaN
# 42      None      NaN
# 43      None      NaN
# 44    Motive      NaN
# s05e21
# 0                          [[Nanette_Faber]] hey , len'
# 1                       [[Hospital_Administrator]] we '
# 2                          [[Leon_Madera]] shh-shh-shh'
# 3                                                   NaN
# 4                                       [[Brass]] who '
# 5                                                   NaN
# 6       [[Ronald_Salter]] i definitely heard something'
# 7                                                   NaN
# 8                                    [[Grissom]] what '
# 9                 [[Jake]] why are you looking at me ?'
# 10                             [[Valerie_Dino]] yeah ?'
# 11    [[Sara]] hey , guys , i found semen in the vic...
# 12                                    [[Robbins]] let '
# 13        [[Hodges]] would you ever bleach your hair ?'
# 14    [[Brass]] news flash from the loony bin two re...
# 15                      [[Hospital_Administrator]] we '
# 16                                [[Leon_Madera]] who '
# 17    [[Brass]] man ... xanax , lanzopine , zoloft ,...
# 18    [[Voice]] all right , here you go , here you g...
# 19                                  [[Leon_Madera]] no'
# 20    [[Sara]] according to the video logs , the vic...
# 21    [[Voice_(woman)]] all past-level-three patient...
# 22                    [[Joanne_McKay]] hey , hey , hey'
# 23                      [[Grissom]] this stuff is dark'
# 24                                   [[Valerie_Dino]] '
# 25                     [[Adam_Trent]] did i kill him ?'
# 26               [[Sara]] not a word about suffocation'
# 27                     [[Sara]] where is nurse mckay ?'
# 28    [[Sara]] this must be the photo that nurse mck...
# 29    [[Sara]] when my father died , my mother came ...
# 30                               [[Grissom]] excuse me'
# 31                      [[Sara]] acoustic archeology ?'
# 32           [[Sara]] the hair from the brush in adam '
# 33              [[Joanne_McKay]] you need to stop this'
# 34                              [[Joanne_McKay]] hey !'
# 35                          [[Joanne_McKay]] hang on !'
# 36    [[Brass]] you manipulated the situation and to...
# Name: dialogue, dtype: object
#    scene_id                                         scene_text  in_summary  \
# 3         3  [' ( One of the inmates stands at the window w...           0
# 5         5  [" ( The door opens and the gurney with Robbie...           0
# 7         7  [' ( Sara is using the ALS on the bed sheets l...           0
#
#   aspects dialogue
# 3    None      NaN
# 5    None      NaN
# 7    None      NaN
# s02e06
# 0                           [[Benjamin_Jennings]] no !'
# 1                  [[Grissom]] call said one dead body'
# 2                         [[Nick]] see that lividity ?'
# 3                                       [[Catherine]] '
# 4                    [[Brass]] body is shelley danvers'
# 5                         [[Brass]] ... found her here'
# 6                             [[Sara]] flour , maybe ?'
# 7                                         [[Warrick]] '
# 8                             [[Robbins]] oliver dunne'
# 9                                       [[Brass]] you '
# 10                             [[Nick]] i feel like i '
# 11                     [[Catherine]] oh , i hope that '
# 12    [[Catherine]] brass , i need you to get record...
# 13                     [[Father_Powell]] gil grissom ?'
# 14    [[Catherine]] and you can verify that when she...
# 15    [[Sara]] two men were shot and killed and you ...
# 16                         [[Father_Powell]] h-hello ?'
# 17    [[Kim_Marita]] i told you we have no record sh...
# 18    [[Brass]] no hotel employee checked in on the ...
# 19               [[Nick]] murder scene was compromised'
# 20                 [[Brass]] anyone up for breakfast ?'
# 21                 [[Nick]] misunderstood the priest ?'
# 22              [[Grissom]] tell me about your brother'
# 23    [[Grissom]] did you learn to throw pizzas in p...
# 24     [[Sara]] anything on the list besides the tie ?'
# 25                                       [[Sara]] whoa'
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                 [[Sara]] hemoglobin'
# 30                                 [[Sara]] hey , nick'
# 31                                                  NaN
# 32               [[Nick]] looks like it jammed , huh ?'
# 33                       [[Greg]] blood from jennings '
# 34        [[Bobby_Dawson]] the striaions are different'
# 35                              [[Roger_Jennings]] he '
# 36    [[Grissom]] the bullet jammed in the feed , di...
# 37    [[Tina_Kolas]] wait , are you saying shelley d...
# 38                                        [[Sara]] hey'
# 39           [[Robin_Childs_(district_attorney)]] do n'
# 40    [[Grissom]] explain how bits of your skin got ...
# 41                                                  NaN
# 42                         [[Grissom]] i know that we '
# 43                                     [[Grissom]] hey'
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 26        26  [' ( NICK walks out of the trailer and looks a...           0
# 27        27  [' ( SARA opens her kit . )', ' ( She uses a s...           0
# 28        28  [' ( Meanwhile , NICK uses the stick to swish ...           0
# 31        31  [' ( The jail doors open . )', ' ( An officer ...           0
# 40        40  [" ( A photograph of the injuries on OLIVER DU...           1
# 41        41  [' ( Quick pulses of a series of legal forms w...           0
# 42        42  [' ( GRISSOM walks into the church . )', ' ( F...           0
# 43        43  [' [[Grissom]] hey', ' [[Catherine]] oh', " [[...           0
#
#    aspects dialogue
# 26    None      NaN
# 27    None      NaN
# 28    None      NaN
# 31    None      NaN
# 40    None      NaN
# 41    None      NaN
# 42    None      NaN
# 43    None      NaN
# s04e10
# 0                       [[Construction_Worker]] boss !'
# 1     [[Grissom]] well , clean surfaces make for goo...
# 2     [[Foreman]] you know , i lose an hour a day cl...
# 3     [[Grissom]] take a look at his head , tell me ...
# 4                                     [[Nick]] fellows'
# 5                        [[K-9_Officer]] distinguish !'
# 6                                         [[Sara]] it '
# 7       [[Robbins]] congealed blood in the pericardium'
# 8                                                   NaN
# 9        [[Archie_Johnson]] they say in america , you '
# 10    [[Brass]] mr curtwell , where were you this we...
# 11    [[Ashley_Curtwell]] my parents died in a car a...
# 12                                     [[Robbins]] it '
# 13                               [[Mr._Haddick]] that '
# 14      [[Bobby_Dawson]] no gsr on either the husband '
# 15    [[Warrick]] hey , sanders , you got anything o...
# 16    [[Sara]] seventy-two-degree impact angle puts ...
# 17          [[Nick]] hey , catherine , feel like doin '
# 18                                                  NaN
# 19                           [[Catherine]] okay , boys'
# 20    [[Bobby_Dawson]] so standard velocity for a ni...
# 21                                   [[Brass]] here i '
# 22                              [[Warrick]] nice kicks'
# 23    [[Mr._Lizzio]] you good for nothing little b*s...
# 24        [[Brass]] so , benny , for the record , you '
# 25                           [[Warrick]] did he roll ?'
# 26    [[Young_Mother]] yeah , i heard gunfire a coup...
# 27           [[Johnnie]] she called you guys , right ?'
# 28       [[Nick]] and this is the gun that you fired ?'
# 29                           [[Brass]] aaron gilbert ?'
# 30                                     [[Brass]] that '
# 31                          [[Sara]] we have a problem'
# 32    [[Sara]] that hand that holds the wallet is th...
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 8          8  [' ( WARRICK swabs the hammer heads and tests ...           0
# 18        18  [' ( CATHERINE makes gel molds . )', ' ( Cut t...           0
#
#    aspects dialogue
# 8     None      NaN
# 18    None      NaN
# s05e08
# 0          [[Wendy_Garner]] officer ... thank god you '
# 1                             [[David_Phillips]] that '
# 2                                      [[Warrick]] wow'
# 3     [[Robbins]] genital wounds were more profound ...
# 4     [[Officer_Mann]] clocked the thunderbird doing...
# 5     [[Catherine]] ran her prints through afis and ...
# 6                      [[Mia_Dickerson]] okay , wendy '
# 7     [[Aaron_Laner]] wendy just bought her wedding ...
# 8     [[Sara]] mr laner , i need to ask you a person...
# 9                        [[Grissom]] this is confusing'
# 10              [[Stage_Manager]] all right , this way'
# 11                             [[Stage_Manager]] that '
# 12                       [[Bev]] okay , so on tonight '
# 13    [[Dr._Mercer]] the law requires re-gender cand...
# 14                                        [[Sara]] hey'
# 15    [[Greg]] hey , these are the pills eric collec...
# 16                                   [[Grissom]] hello'
# 17                          [[Mia_Dickerson]] hey , i '
# 18                                   [[Brass]] lepidro'
# 19     [[Amber_Hamshaw]] bye-bye , scrumptious pumpkin'
# 20    [[Mona_Lavalle]] in the sanctuary alliance i s...
# 21    [[Nick]] wendy lived here at 118 sunshine road...
# 22                                   [[Warrick]] what '
# 23                                  [[Nick]] catherine'
# 24                             [[Robbins]] piano wires'
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                         [[Nick]] hi'
# 29    [[Catherine]] jacqui got an afis hit off the b...
# 30    [[Mia_Dickerson]] so , i heard brass arrested ...
# 31                        [[Francis]] this is absurd !'
# 32                            [[Amber_Hamshaw]] i do n'
# 33                        [[Woman_1]] okay , now what '
# 34                                [[Catherine]] wendy '
# 35    [[Catherine]] so the man admits to murder but ...
# 36                          [[Grissom]] i thought you '
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 25        25  [' ( Catherine takes out the various items tak...           0
# 26        26  [' ( In the DNA Lab , Mia inverts the latex gl...           0
# 27        27  [' ( Nick is working on the computer . )', " (...           0
#
#    aspects dialogue
# 25    None      NaN
# 26    None      NaN
# 27    None      NaN
# s03e05
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5     [[Zephyr]] i need one volunteer from the audie...
# 6           [[Brass]] welcome to the house of illusion'
# 7     [[Brass]] i got a bunch of police officers , u...
# 8                          [[Grissom]] dull as a spoon'
# 9          [[Zephyr]] nothing is as it seems , is it ?'
# 10                                 [[Catherine]] what '
# 11               [[Nick]] ooh ... rock and roll , baby'
# 12    [[Warrick]] big glass box and all i got is a p...
# 13                                    [[Sara]] bye-bye'
# 14    [[Punky_Dillinger]] at this point of the trick...
# 15                    [[Grissom]] magicians of zephyr '
# 16                                  [[Catherine]] you '
# 17    [[SARA_(PRELAP)]] the stagehand was lying abou...
# 18     [[Sara]] i got his palm print off the trap door'
# 19                           [[Brass]] hey , hey , hey'
# 20             [[Nick]] the videotape from last night '
# 21                           [[Sara]] i know you did n'
# 22                                    [[Grissom]] whoa'
# 23                                                  NaN
# 24                                 [[Toby_Arcane]] it '
# 25                                  [[Greg]] the band '
# 26    [[Nick]] i showed the road manager a copy of t...
# 27                                  [[Catherine]] gone'
# 28                       [[Warrick]] goodyear wrangler'
# 29                                 [[Sara]] nice house'
# 30                     [[Grissom]] las vegas crime lab'
# 31                                      [[Sara]] sorry'
# 32                                      [[Nick]] what '
# 33                                     [[Sara]] there '
# 34                                    [[Sara]] hello ?'
# 35     [[Keith_Castle]] look , i got a family , okay ?'
# 36                       [[Catherine]] samantha dean ?'
# 37    [[Catherine]] gus kenyon looked up your number...
# 38                                                  NaN
# 39    [[Brass]] how long have you been working for t...
# 40                              [[Warrick]] ford f-150'
# 41                                 [[Catherine]] there'
# 42    [[Catherine]] there was a scuff on samantha de...
# 43                                  [[Matilda]] sadie '
# 44    [[Zephyr]] ladies and gentlemen : i know you a...
# 45                                        [[Sara]] it '
# 46                                     [[Robbins]] he '
# 47                  [[Toby_Arcane]] come on , trust me'
# 48                [[Samantha_Dean]] this is ridiculous'
# 49                                                  NaN
# 50                                 [[Grissom]] warrick'
# 51                                                  NaN
# 52    [[Warrick]] zephyr dillinger and punky the sta...
# 53                                                  NaN
# 54                            [[Grissom]] he fooled us'
# 55          [[Grissom]] i think this room is shrinking'
# 56    [[Zephyr]] nothing is what it seems but i fool...
# 57                               [[Grissom]] officer ?'
# 58                                                  NaN
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 0          0  [' ( ZEPHYR walks out on stage , pulls out two...           0
# 1          1  [' ( Overhead view of a large intersection on ...           0
# 2          2  [' ( ZEPHYR is on stage holding up the two swo...           0
# 3          3  [' ( Close up of an overhead view of a large i...           0
# 4          4  [' ( Back to ZEPHYR on stage . )', " ( He hold...           0
# 23        23  [' ( The hammer hits the nail with a loud clan...           0
# 38        38  [' ( CATHERINE walks down the pathway toward h...           0
# 40        40  [' [[Warrick]] ford f-150', " ( WARRICK and SA...           0
# 41        41  [' ( CATHERINE takes out the CD booklet and fl...           1
# 42        42  [' ( CATHERINE walks into the room and heads f...           1
# 43        43  [' ( MATILDA is standing outside next to the b...           0
# 44        44  [' ( ZEPHYR steps out on stage as the audience...           1
# 45        45  [' ( Camera close up of a large nail stuck in ...           1
# 46        46  [' ( ROBBINS and GRISSOM go over the prelimina...           1
# 47        47  [" ( A bag full of magician 's supplies is emp...           0
# 48        48  [' ( BRANDON DEAN sits on the living room floo...           1
# 49        49  [' ( GRISSOM sits at his desk holding the coin...           0
# 50        50  [' ( GRISSOM exits his office and walks down t...           0
# 51        51  [' ( The refrigeration unit is opened and the ...           0
# 52        52  [" ( Camera close up of a website about the 'A...           1
# 53        53  [' ( With the piece of finger tip that GRISSOM...           0
# 54        54  [' ( Close up of the computer screen . )', " (...           1
# 55        55  [' ( GRISSOM walks cautiously down the spiral ...           0
# 56        56  [' ( GRISSOM walks through the passageway . )'...           1
# 57        57  [' ( ZEPHYR is handcuffed behind his back and ...           0
# 58        58  [' ( Sitting in the back seat of the car , ZEP...           0
#
#         aspects dialogue
# 0          None      NaN
# 1          None      NaN
# 2          None      NaN
# 3          None      NaN
# 4          None      NaN
# 23         None      NaN
# 38         None      NaN
# 40         None      NaN
# 41     Evidence      NaN
# 42     Evidence      NaN
# 43         None      NaN
# 44         None      NaN
# 45         None      NaN
# 46  Death cause      NaN
# 47         None      NaN
# 48       Motive      NaN
# 49         None      NaN
# 50         None      NaN
# 51         None      NaN
# 52     Evidence      NaN
# 53         None      NaN
# 54     Evidence      NaN
# 55         None      NaN
# 56       Motive      NaN
# 57         None      NaN
# 58         None      NaN
# s04e22
# 0                                  [[Interrogator]] i '
# 1          [[Brass]] two shots to the back of the head'
# 2                                    [[Catherine]] he '
# 3                                    [[Sara]] no ticks'
# 4                             [[Croupier]] insurance ?'
# 5     [[Grissom]] smells like the cleaning crew just...
# 6                             [[Robbins]] for what it '
# 7                                                   NaN
# 8                   [[Grissom]] a computer in his shoe'
# 9            [[Joseph_Greene_(landlord)]] teddy deller'
# 10                    [[Warrick]] two taps to the head'
# 11                                                  NaN
# 12      [[Chris_Bezich]] so you just got the day off ?'
# 13    [[David_Hodges]] the glass fragments you found...
# 14                                        [[Sara]] hey'
# 15    [[Warrick]] grissom , i have been in vegas my ...
# 16                       [[Brass]] seth landers does n'
# 17                        [[Brass]] jacking sam braun '
# 18                  [[Catherine]] what are you doing ?'
# 19    [[Sara]] nick said the budget for the promotio...
# ...
# 33                      [[Brass]] you recognize this ?'
# 34                           [[Catherine]] oh ... you '
# Name: dialogue, dtype: object
#    scene_id                                         scene_text  in_summary  \
# 1         1  [' ( LAUREL TRENT lies dead on the driveway pa...           0
#
#   aspects dialogue
# 1    None      NaN
# s01e23
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                           [[Brass]] eileen jane snow'
# 5             [[Grissom]] listen , no emotions in here'
# 6      [[Sara]] i have tape-lifted , roll-lifted -- i '
# 7                                     [[Grissom]] you '
# 8                      [[Nick]] what can you tell us ?'
# 9     [[Greg_Sanders]] the semen taken from this mor...
# 10     [[Sheriff_Brian_Mobley]] catherine , you busy ?'
# 11           [[Sara]] hey , warrick you got a second ?'
# 12    [[Nick]] hey , gil , you want to give me the s...
# 13        [[Agent_Rick_Culpepper]] you all got my page'
# 14                                   [[Nick]] freeze !'
# 15                                  [[Catherine]] fast'
# 16    [[Grissom]] i was expecting something a little...
# 17               [[Brass]] what about paul millander ?'
# 18           [[Agent_Rick_Culpepper]] okay , listen up'
# 19                                                  NaN
# 20                 [[Agent_Rick_Culpepper]] oh ... it '
# 21                               [[Grissom]] culpepper'
# 22    [[Catherine]] starting to look like deja vu al...
# 23                      [[Grissom]] what did you get ?'
# 24    [[Dr._Albert_Robbins]] cross-hatched leather ,...
# 25                         [[Agent_Rick_Culpepper]] i '
# 26                                [[Grissom]] you ca n'
# 27    [[Paula_Francis_(tv_Reporter)]] details of the...
# 28    [[Sheriff_Brian_Mobley]] the fbi did me a favo...
# 29                             [[Nick]] you know , it '
# 30                                 [[Catherine]] hey !'
# 31    [[Grissom]] we should reexamine each victim --...
# 32              [[Greg_Sanders]] hunter f. baumgartner'
# 33    [[Catherine]] you think anything illegal goes ...
# 34                                    [[Sara]] i did n'
# 35                                  [[Nick]] yeah , i '
# 36                                  [[Grissom]] goggle'
# 37                             [[Grissom]] mr goggle ?'
# 38                          [[Syd_Goggle]] gil grissom'
# 39    [[Sheriff_Brian_Mobley]] we can say unequivoca...
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 0          0  [' ( Camera holds over the city . )', ' ( Thun...           0
# 1          1  [' ( The front left glass door is open . )', '...           0
# 2          2  [' ( Camera moves slowly down the hallway towa...           0
# 3          3  [' ( EILEEN SNOW suddenly gets up . )', ' ( Sh...           1
# 19        19  [' ( SARA walks cautiously through the grocery...           0
#
#                aspects dialogue
# 0                 None      NaN
# 1                 None      NaN
# 2                 None      NaN
# 3   Crime scene,Victim      NaN
# 19                None      NaN
# s03e21
# 0                                                   NaN
# 1                        [[Captain]] hey , folks , we '
# 2                                                   NaN
# 3                                [[Brass]] the victim '
# 4                       [[Catherine]] all right , let '
# 5                                      [[Nick]] where '
# 6                         [[Nick]] what have you got ?'
# 7            [[Lockwood]] this is death valley , huh ?'
# 8     [[Lockwood]] helicopter tour pilot noted it an...
# 9                                    [[Brass]] oh , i '
# 10                                   [[USDA_Guard]] i '
# 11                             [[Catherine]] thank you'
# 12                                        [[Sara]] hey'
# 13    [[Robbins]] treated himself to a hamburger wit...
# 14                          [[Nick]] hey , fashionista'
# 15    [[Robbins]] our horse trainer has paramortem b...
# 16    [[Nick]] miss fitzgerald , your shoe print was...
# 17         [[Sara]] getting a strange sense of deja vu'
# 18    [[Grissom]] the tranquilizer gun looks like a ...
# 19       [[Brass]] what were you doing on that plane ?'
# 20                                                  NaN
# 21                                   [[Warrick]] hello'
# 22              [[Sara]] do you recognize this dress ?'
# 23     [[Greg]] blood on the paper towels was the vic '
# 24    [[Dr._Stevens]] i came as soon as i got a call...
# 25                  [[Jessie_Menken]] equine necropsy '
# 26             [[Dark-haired_Teenager]] jill frommer ?'
# 27                            [[Alyssa_Jamison]] hello'
# 28    [[Grissom]] according to his receptionist , dr...
# 29             [[Grissom]] did you know that the term '
# 30    [[Brass]] well , you travel with a well-heeled...
# 31                          [[Warrick]] you know jill '
# 32                                                  NaN
# 33                                   [[Lockwood]] mom '
# 34                                                  NaN
# 35                                     [[Lockwood]] ma'
# 36                                                  NaN
# 37    [[Sara]] cisapride and fentanyl -- you care to...
# 38                               [[Warrick]] hi , baby'
# 39                   [[Catherine]] what have you got ?'
# 40                       [[Catherine]] okay , so , we '
# 41    [[Catherine]] find out if the owner is related...
# 42                      [[Brass]] yeah , someone else '
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 0          0  [' ( Camera opens on the sea of clouds at the ...           0
# 2          2  [' ( The camera pans backward and down slowly ...           1
# 20        20  [" ( SARA swabs JILL FROMMER 'S dress . )", ' ...           0
# 32        32  [' ( Officers comb the area looking for the ba...           0
# 34        34  [' ( OFFICERS continue to search for the missi...           0
# 36        36  [' ( WARRICK and SARA each search through a dr...           0
# 40        40  [' ( NICK is in front of the screen . )', ' ( ...           0
# 41        41  [' ( Camera close up of a tray of uncut diamon...           0
# 42        42  [' ( BRASS and GRISSOM interviews RHONE CONFER...           1
#
#             aspects dialogue
# 0              None      NaN
# 2       Crime scene      NaN
# 20             None      NaN
# 32             None      NaN
# 34             None      NaN
# 36             None      NaN
# 40             None      NaN
# 41             None      NaN
# 42  Evidence,Motive      NaN
# s04e06
# 0                                      [[Robbins]] hmm'
# 1                              [[David_Hodges]] there '
# 2                                                   NaN
# 3                                      [[Cook]] order '
# 4     [[David_Hodges]] of all the plant life gathere...
# 5                                  [[Grissom]] grissom'
# 6     [[Catherine]] is the service actually bad out ...
# 7             [[Grissom]] so your dog found the head ?'
# 8     [[Alan_Brooks]] afraid you gon na trip over so...
# 9     [[Grissom]] step away from there , would you p...
# 10    [[Alan_Brooks]] hey , einstein , we going to s...
# 11    [[Dale_Sterling]] i was in the 99th percentile...
# 12              [[Grissom]] hold on a second , fellows'
# 13                                                  NaN
# 14        [[Warrick]] did i miss a memo or something ?'
# 15                            [[Brass]] actually , we '
# 16                                                  NaN
# 17                                     [[Gloria]] yeah'
# 18                                                  NaN
# 19    [[Grissom]] hey , doc , i need to use some of ...
# 20                  [[Grissom]] oh , good , the police'
# 21    [[Grissom]] would you keep an eye on this for ...
# 22    [[Grissom]] you going to just stand there , or...
# 23    [[Grissom]] hey , you think you can fix this w...
# 24    [[Catherine]] everybody in sleepy hollow still...
# 25    [[Dale_Sterling]] just got the blood test resu...
# 26                  [[Grissom]] excuse me , lieutenant'
# 27    [[Alan_Brooks]] look , um , just give me a min...
# 28                        [[Catherine]] what is this ?'
# 29                            [[Greg]] hey , catherine'
# 30     [[Dale_Sterling]] hey ... you have a phone call'
# 31    [[Catherine]] the day ross jenson left vegas ,...
# 32    [[Brass]] did you know your father was having ...
# 33    [[Grissom]] how did you intend to keep the rel...
# 34                        [[Catherine]] you used ross '
# 35    [[Eric_Brooks]] people in town ... they said m...
# 36                                  [[Grissom]] i do n'
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 2          2  [' ( The sign says : PAY AT THE PUMP . )', " (...           0
# 13        13  [" ( CLOSE UP : GRISSOM sprays the wad of pape...           0
# 16        16  [' ( GRISSOM is lying on the office couch with...           0
# 18        18  [' ( GRISSOM drives down the road . )', ' ( He...           0
#
#    aspects dialogue
# 2     None      NaN
# 13    None      NaN
# 16    None      NaN
# 18    None      NaN
# s03e08
# 0     [[FILM_PROCESSOR_(WOMAN)]] okay , this is wher...
# 1                                [[Brass]] i got a d.b'
# 2     [[Brass]] so a kid was driving along and spott...
# 3                             [[Brass]] man or woman ?'
# 4     [[Det._Sulik]] i followed up on the private ma...
# 5                [[Catherine]] find any fingerprints ?'
# 6                    [[Robbins]] come on , you bitch !'
# 7             [[Robbins]] something tells me that is n'
# 8                  [[Warrick]] okay , all right , let '
# 9                                [[Det._Sulik]] hotel '
# 10                                   [[Warrick]] what '
# 11                                 [[Greg]] heard you '
# 12     [[Catherine]] well ... sara , you take that one'
# 13                                                  NaN
# 14                               [[Sara]] hey , guys ?'
# 15    [[Det._Sulik]] how long you been a day guard h...
# 16                          [[Teri_Miller]] i see you '
# 17    [[Warrick]] damn , security guard was telling ...
# 18                  [[Catherine]] so all your editors '
# 19                    [[Nick]] what the heck is that ?'
# 20                    [[Grissom]] what did trace say ?'
# 21    [[Nick]] from the tip down , the slope looks t...
# 22    [[Sara]] you notice all the guys in these movi...
# 23                    [[Grissom]] tissue depth markers'
# 24                                                  NaN
# 25    [[Brass]] so i sent out a community fax to eve...
# 26                              [[Brass]] hey , where '
# 27                                  [[Warrick]] there '
# 28                                                  NaN
# 29                    [[Det._Sulik]] douglas sampson ?'
# 30               [[Catherine]] hey , what do you got ?'
# 31                  [[Brass]] you never met this man ?'
# 32                                                  NaN
# 33    [[Nick]] enrique said he got those boots an sp...
# 34                                   [[Warrick]] brown'
# 35                                                  NaN
# 36           [[Robbins]] warrick stick you with post ?'
# 37                                [[Sara]] susan hodap'
# 38    [[Nick]] this would be a pretty cool little tr...
# 39                           [[Billy_Rattison]] i do n'
# 40    [[Nick]] your ants put the time of death at 19...
# 41                                    [[Warrick]] damn'
# 42                                                  NaN
# 43    [[Grissom]] we sliced the shard into layers of...
# 44                                                  NaN
# 45                                   [[Nick]] two feet'
# 46       [[Billy_Rattison]] what do you all want now ?'
# 47    [[Det._Sulik]] okay , one more time , for the ...
# 48    [[Catherine]] you still have those chills , mr...
# Name: dialogue, dtype: object
#     scene_id                                         scene_text  in_summary  \
# 13        13  [' ( CATHERINE walks into her room and looks a...           0
# 24        24  [' ( A photo of RANDY TRASCHEL runs through th...           0
# 28        28  [' ( The computer printer beeps . )', ' ( CATH...           0
# 32        32  [' ( In the lab , GRISSOM takes the spurs out ...           0
# 35        35  [' ( WARRICK makes his way toward the body . )...           0
# 40        40  [' ( GRISSOM and NICK walk through the stalls ...           0
# 41        41  [' ( SARA walks through the hallway . )', ' [[...           0
# 42        42  [" ( Inside the room , a Lab Tech draws a samp...           0
# 43        43  [' ( GRISSOM and NICK work on the piece of met...           0
# 44        44  [' ( GRISSOM puts a photo of the ant-infested ...           0
# 45        45  [' ( Curly , the bull , with his large horns i...           0
# 46        46  [' ( BILLY RATTISON walks past the corral and ...           1
# 47        47  [' ( CATHERINE and SARA are in the observation...           0
# 48        48  [' ( The door opens . )', ' ( CATHERINE and SA...           1
#
#         aspects dialogue
# 13         None      NaN
# 24         None      NaN
# 28         None      NaN
# 32     Evidence      NaN
# 35         None      NaN
# 40         None      NaN
# 41         None      NaN
# 42         None      NaN
# 43     Evidence      NaN
# 44         None      NaN
# 45         None      NaN
# 46  Death cause      NaN
# 47         None      NaN
# 48         None      NaN
# s01e19
# 0                               [[Gwen_Anderson]] no !'
# 1                                [[Grissom]] excuse me'
# 2     [[Catherine]] jim , dispatch said this is a ki...
# 3              [[Steve_Anderson]] are you sure he wo n'
# 4       [[Gwen_Anderson]] do my boys have to be here ?'
# 5                                     [[Grissom]] sara'
# 6                 [[Warrick]] you see this spiderweb ?'
# 7                              [[Catherine]] oh , you '
# 8                           [[Warrick]] what you got ?'
# 9                 [[Sara]] what do you mean you have n'
# 10    [[Warrick]] yeah , this mold i made of that sh...
# 11                               [[Sara]] ransom note '
# 12                     [[Warrick]] get those dogs back'
# 13    [[Paula_Francis]] the andersons , who own a pr...
# 14                       [[Dr._Albert_Robbins]] i ca n'
# 15                [[Grissom]] are those from anderson '
# 16                             [[Grissom]] i hear you '
# 17                                      [[Grissom]] i '
# 18    [[Tyler_Anderson]] i was playing ball in the b...
# 19          [[Catherine]] so what are we looking for ?'
# 20                                      [[Nick]] here '
# 21                             [[Grissom]] the mother '
# 22                         [[Needra_Fenway]] thank you'
# 23                     [[Steve_Anderson]] needra did n'
# 24    [[Catherine]] a wife kills her baby to get bac...
# 25                    [[Reporter_(man)]] baby killer !'
# 26                                   [[Catherine]] ice'
# 27       [[Gwen_Anderson]] i never meant to hurt tyler'
# 28                             [[Steve_Anderson]] look'
# 29           [[Sara]] same color as the fiber in zack '
# 30    [[Warrick]] okay , this is the 911 call from t...
# 31    [[Brad_Lewis]] my colleagues , messrs. landry ...
# 32      [[Warrick]] i was just coming to meet you guys'
# 33                   [[Tyler]] i was watching the boys'
# 34              [[Catherine]] now i know why you did n'
# 35                            [[Grissom]] your family '
# Name: dialogue, dtype: object
# Empty DataFrame
# Columns: [scene_id, scene_text, in_summary, aspects, dialogue]
# Index: []

# %%
path_screenplays_scenes='coref/csi-corpus/screenplay_summarization/scene_level_n_aspects'
eps=[]

for ep in listdir(path_screenplays_scenes):
    #print(ep)
    annotated_scenes=pd.read_csv(path_screenplays_scenes+'/'+ep)
    eps.append(ep.split('.csv')[0])
    

annotated_scenes=pd.read_csv(path_screenplays_scenes+'/'+'s02e15.csv')
annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("\[\[.*?\]\]", "")
annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("n't", "nt")
#annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace(" 're", "'re")
#annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace(" 've", "'ve")


annotated_scenes['words']=annotated_scenes.scene_text.str.replace('[^\w\s]','').str.split().tolist()
annotated_scenes['word_count']=annotated_scenes['words'].apply(len)
print(annotated_scenes['words'][2
                        ])



print(annotated_scenes['word_count'].sum())
# Out:
# ['GRISSOM', 'moves', 'toward', 'an', 'old', 'white', 'pickup', 'truck', 'He', 'looks', 'into', 'the', 'carriage', 'and', 'sees', 'a', 'dead', 'body', 'behind', 'the', 'driver', 's', 'wheel', 'a', 'rodent', 'on', 'the', 'cadaver', 's', 'left', 'shoulder']
# 7435

# %%
"""   
    #annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("n't", "nt")
    #annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace(" 're", "'re")
    #annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace(" 've", "'ve")


    
    
   
    
    
    
"""
# Out:
# '   \n    #annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace("n\'t", "nt")\n    #annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace(" \'re", "\'re")\n    #annotated_scenes.scene_text = annotated_scenes.scene_text.str.replace(" \'ve", "\'ve")\n\n\n    \n    \n   \n    \n    \n    \n'
